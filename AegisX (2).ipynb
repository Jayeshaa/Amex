# %% [markdown]
# DATA COLLECTION

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/kaggle.json
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# !unzip creditcardfraud.zip
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# chmod: cannot access '/root/kaggle.json': No such file or directory
# ...
# creditcardfraud.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  creditcardfraud.zip
# replace creditcard.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.head()
# import joblib
# joblib.dump(df, 'train3.pkl')
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# CLEANING AND TRAINING DATA

# %%
x = df.drop('Class', axis=1)
y = df['Class']

# %%
df.hist(bins=30, figsize=(30, 30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
colors = ['#0101DF','#DF0101']
sns.countplot(x='Class', data=df, palette=colors)
plt.title('Class Distribution \n Not Fraud:0 || Fraud:1', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))
amount_val = df['Amount'].values
time_val = df['Time'].values

sns.distplot(amount_val, ax=ax[0], color='g')
ax[0].set_title('Distribution of Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])

plt.show()
# Out:
# <ipython-input-12-10d90d2fec15>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amount_val, ax=ax[0], color='g')
# <ipython-input-12-10d90d2fec15>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(time_val, ax=ax[1], color='b')

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, RobustScaler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split

# %%
s = StandardScaler()
r = RobustScaler()
df['scaled_amt'] = r.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = r.fit_transform(df['Time'].values.reshape(-1,1))
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
scaled_amt = df['scaled_amt']
scaled_time = df['scaled_time']
df.drop(['scaled_time', 'scaled_amt'], axis=1, inplace=True)

# %%
# creating pickle file for training data

# %%
# import joblib
# import sys
# joblib.dump(df, 'train2.pkl')
df.head()
# print(sys.version)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Class
# ...

# %%
df = df.sample(frac=1)
f_df = df.loc[df['Class'] == 1]
n_df = df.loc[df['Class'] == 0] [:492]
normal_distributed_df = pd.concat([f_df, n_df])
new_df = normal_distributed_df.sample(frac=1, random_state=42)

# %%
grouped_data = new_df['Class'].value_counts()
plt.figure(figsize=(10, 6))  
grouped_data.plot(kind='bar')  
plt.xlabel('Class')  
plt.ylabel('Count') 
plt.title('Equally Distributed class')  
plt.show()

# %%
corr_matrix = new_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V17', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V17')  
plt.title('Boxplot') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V14', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V14')  
plt.title('Boxplot') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V12', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V12')  
plt.title('Boxplot') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V10', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V10')  
plt.title('Boxplot') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V19', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V19')  
plt.title('Boxplot') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V2', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V2')  
plt.title('Boxplot') 
plt.show()

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x='Class', y='V4', data=new_df) 
plt.xlabel('Class') 
plt.ylabel('V4')  
plt.title('Boxplot') 
plt.show()

# %% [markdown]
# Removing outliers using IQR

# %%
import numpy as np

# %%
v14_fraud = new_df['V14'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v14_fraud, 25), np.percentile(v14_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v14_iqr = q75 - q25
print('iqr: {}'.format(v14_iqr))
# Out:
# Quartile 25: -9.692722964972386 | Quartile 75: -4.282820849486865
# iqr: 5.409902115485521

# %%
v14_cut_off = v14_iqr * 1.5
v14_lower, v14_upper = q25 - v14_cut_off, q75 + v14_cut_off
print('Cut Off: {}'.format(v14_cut_off))
print('V14 Lower: {}'.format(v14_lower))
print('V14 Upper: {}'.format(v14_upper))
# Out:
# Cut Off: 8.114853173228282
# V14 Lower: -17.807576138200666
# V14 Upper: 3.8320323237414167

# %%
new_df = new_df.drop(new_df[(new_df['V14'] > v14_upper) | (new_df['V14'] < v14_lower)].index)

# %%
v17_fraud = new_df['V17'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v17_fraud, 25), np.percentile(v17_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v17_iqr = q75 - q25
print('iqr: {}'.format(v17_iqr))
# Out:
# Quartile 25: -11.8875700201872 | Quartile 75: -1.3117320155731325
# iqr: 10.575838004614067

# %%
v17_cut_off = v17_iqr * 1.5
v17_lower, v17_upper = q25 - v17_cut_off, q75 + v17_cut_off
print('Cut Off: {}'.format(v17_cut_off))
print('V17 Lower: {}'.format(v17_lower))
print('V17 Upper: {}'.format(v17_upper))
# Out:
# Cut Off: 15.8637570069211
# V17 Lower: -27.7513270271083
# V17 Upper: 14.552024991347967

# %%
new_df = new_df.drop(new_df[(new_df['V17'] > v17_upper) | (new_df['V17'] < v17_lower)].index)

# %%
v12_fraud = new_df['V12'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v12_fraud, 25), np.percentile(v12_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v12_iqr = q75 - q25
print('iqr: {}'.format(v17_iqr))
# Out:
# Quartile 25: -8.67303320439115 | Quartile 75: -2.893030568676315
# iqr: 10.575838004614067

# %%
v12_cut_off = v12_iqr * 1.5
v12_lower, v12_upper = q25 - v12_cut_off, q75 + v12_cut_off
print('Cut Off: {}'.format(v12_cut_off))
print('V12 Lower: {}'.format(v12_lower))
print('V12 Upper: {}'.format(v12_upper))
# Out:
# Cut Off: 8.670003953572252
# V12 Lower: -17.3430371579634
# V12 Upper: 5.776973384895937

# %%
new_df = new_df.drop(new_df[(new_df['V12'] > v12_upper) | (new_df['V12'] < v12_lower)].index)

# %%
v10_fraud = new_df['V10'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v10_fraud, 25), np.percentile(v10_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v10_iqr = q75 - q25
print('iqr: {}'.format(v10_iqr))
# Out:
# Quartile 25: -7.466658535821847 | Quartile 75: -2.5118611381562523
# iqr: 4.954797397665595

# %%
v10_cut_off = v10_iqr * 1.5
v10_lower, v10_upper = q25 - v10_cut_off, q75 + v10_cut_off
print('Cut Off: {}'.format(v10_cut_off))
print('V10 Lower: {}'.format(v10_lower))
print('V10 Upper: {}'.format(v10_upper))
# Out:
# Cut Off: 7.432196096498393
# V10 Lower: -14.89885463232024
# V10 Upper: 4.92033495834214

# %%
new_df = new_df.drop(new_df[(new_df['V10'] > v10_upper) | (new_df['V10'] < v10_lower)].index)

# %%
v2_fraud = new_df['V2'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v2_fraud, 25), np.percentile(v2_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v2_iqr = q75 - q25
print('iqr: {}'.format(v2_iqr))
# Out:
# Quartile 25: 1.13313858781029 | Quartile 75: 4.14198623236944
# iqr: 3.0088476445591503

# %%
v2_cut_off = v2_iqr * 1.5
v2_lower, v2_upper = q25 - v14_cut_off, q75 + v14_cut_off
print('Cut Off: {}'.format(v2_cut_off))
print('V2 Lower: {}'.format(v2_lower))
print('V2 Upper: {}'.format(v2_upper))
# Out:
# Cut Off: 4.5132714668387255
# V2 Lower: -6.981714585417992
# V2 Upper: 12.256839405597722

# %%
new_df = new_df.drop(new_df[(new_df['V2'] > v2_upper) | (new_df['V2'] < v2_lower)].index)

# %%
v4_fraud = new_df['V4'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v4_fraud, 25), np.percentile(v4_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v4_iqr = q75 - q25
print('iqr: {}'.format(v4_iqr))
# Out:
# Quartile 25: 2.1795614433335553 | Quartile 75: 5.856878042338015
# iqr: 3.6773165990044596

# %%
v4_cut_off = v4_iqr * 1.5
v4_lower, v4_upper = q25 - v4_cut_off, q75 + v4_cut_off
print('Cut Off: {}'.format(v4_cut_off))
print('V4 Lower: {}'.format(v4_lower))
print('V4 Upper: {}'.format(v4_upper))
# Out:
# Cut Off: 5.515974898506689
# V4 Lower: -3.336413455173134
# V4 Upper: 11.372852940844705

# %%
new_df = new_df.drop(new_df[(new_df['V4'] > v4_upper) | (new_df['V4'] < v4_lower)].index)

# %%
v11_fraud = new_df['V11'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v11_fraud, 25), np.percentile(v11_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v11_iqr = q75 - q25
print('iqr: {}'.format(v11_iqr))
# Out:
# Quartile 25: 1.8423736030381876 | Quartile 75: 4.80880090398749
# iqr: 2.9664273009493023

# %%
v11_cut_off = v11_iqr * 1.5
v11_lower, v11_upper = q25 - v11_cut_off, q75 + v11_cut_off
print('Cut Off: {}'.format(v11_cut_off))
print('V11 Lower: {}'.format(v11_lower))
print('V11 Upper: {}'.format(v11_upper))
# Out:
# Cut Off: 4.449640951423953
# V11 Lower: -2.607267348385766
# V11 Upper: 9.258441855411444

# %%
new_df = new_df.drop(new_df[(new_df['V11'] > v11_upper) | (new_df['V11'] < v11_lower)].index)

# %%
v19_fraud = new_df['V19'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v19_fraud, 25), np.percentile(v19_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v19_iqr = q75 - q25
print('iqr: {}'.format(v19_iqr))
# Out:
# Quartile 25: -0.48273527707520797 | Quartile 75: 1.6854727885090899
# iqr: 2.168208065584298

# %%
v19_cut_off = v19_iqr * 1.5
v19_lower, v19_upper = q25 - v19_cut_off, q75 + v19_cut_off
print('Cut Off: {}'.format(v19_cut_off))
print('V19 Lower: {}'.format(v19_lower))
print('V19 Upper: {}'.format(v19_upper))
# Out:
# Cut Off: 3.252312098376447
# V19 Lower: -3.735047375451655
# V19 Upper: 4.937784886885536

# %%
new_df = new_df.drop(new_df[(new_df['V19'] > v19_upper) | (new_df['V19'] < v19_lower)].index)

# %%
from sklearn.decomposition import PCA

# %%
x = new_df.drop('Class', axis=1)
y = new_df['Class']
pca = PCA(n_components=2)  
X_pca = pca.fit_transform(x)

reduced_data = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
reduced_data['Class'] = y

plt.figure(figsize=(10, 8))
plt.scatter(reduced_data.loc[reduced_data['Class'] == 0, 'PC1'], reduced_data.loc[reduced_data['Class'] == 0, 'PC2'], label='Non Fraud', alpha=0.5)
plt.scatter(reduced_data.loc[reduced_data['Class'] == 1, 'PC1'], reduced_data.loc[reduced_data['Class'] == 1, 'PC2'], label='Fraud', alpha=0.5)
plt.xlabel('A')
plt.ylabel('B')
plt.title('PCA Dimensionality Reduction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,auc,roc_auc_score
from sklearn.metrics import classification_report
import matplotlib.gridspec as gridspec

# %%
gs = gridspec.GridSpec(28, 1)
plt.figure(figsize=(6,28*4))
for i, col in enumerate(new_df[new_df.iloc[:,0:28].columns]):
    ax5 = plt.subplot(gs[i])
    sns.distplot(new_df[col][new_df.Class == 1], bins=50, color='r')
    sns.distplot(new_df[col][new_df.Class == 0], bins=50, color='g')
    ax5.set_xlabel('')
    ax5.set_title('feature: ' + str(col))
plt.show()
# Out:
# <ipython-input-56-6a45d843e594>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df[col][new_df.Class == 1], bins=50, color='r')
# <ipython-input-56-6a45d843e594>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
print("Train_set size:", len(y_train))
# Out:
# Train_set size: 720

# %%
print("fraud cases in test_set: ", sum(y_test))
# Out:
# fraud cases in test_set:  83

# %% [markdown]
# DATA MODELING AND EVALUATION

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = new_df.drop('Class', axis=1)
y = new_df['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90        98
#            1       0.89      0.87      0.88        83
#
#     accuracy                           0.89       181
#    macro avg       0.89      0.89      0.89       181
# weighted avg       0.89      0.89      0.89       181

# %%
cm_1 = confusion_matrix(y_test,y_pred)

sns.heatmap(cm_1, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for KNN',fontsize=17)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
rf = RandomForestClassifier(n_estimators=100)
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        98
#            1       0.94      0.89      0.91        83
#
#     accuracy                           0.92       181
#    macro avg       0.92      0.92      0.92       181
# weighted avg       0.92      0.92      0.92       181

# %%
cm_2 = confusion_matrix(y_test,y_pred)

sns.heatmap(cm_2, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Random Forest',fontsize=17)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
nb = GaussianNB()
nb.fit(x_train, y_train)
y_pred = nb.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91        98
#            1       0.93      0.84      0.89        83
#
#     accuracy                           0.90       181
#    macro avg       0.91      0.90      0.90       181
# weighted avg       0.90      0.90      0.90       181

# %%
cm_3 = confusion_matrix(y_test,y_pred)

sns.heatmap(cm_3, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Naive Bayes',fontsize=17)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
log = LogisticRegression()
log.fit(x_train, y_train)
y_pred = log.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92        98
#            1       0.90      0.92      0.91        83
#
#     accuracy                           0.92       181
#    macro avg       0.92      0.92      0.92       181
# weighted avg       0.92      0.92      0.92       181

# %%
cm_4 = confusion_matrix(y_test,y_pred)

sns.heatmap(cm_4, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Logistic Regression',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# %%
models = [('Logistic Regression', LogisticRegression()), 
          ('knn', KNeighborsClassifier()), 
          ('Random Forest', RandomForestClassifier()),
          ('Naive Bayes', GaussianNB())]

results = []

for model_name, model in models:
    scores = cross_val_score(model, x, y, cv=5, scoring='f1_macro')
    results.append((model_name, scores))

fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot([score for _, score in results], labels=[model_name for model_name, _ in results])
ax.set_title('Machine Learning Models on Imbalanced Credit Card Fraud Dataset')
ax.set_ylabel('F1 Macro Score')
plt.show()

# %% [markdown]
# WORKING WITH IMBALANCE DATA

# %% [markdown]
# COLLECTING IMBALANCE DATA

# %%
import pandas as pd
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.dropna()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# USING IMBALANCE DATA FOR TRAINING

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Class', axis=1)
Y = df['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# DATA MODELING AND EVALUATION

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       1.00      0.05      0.10        98
#
#     accuracy                           1.00     56962
#    macro avg       1.00      0.53      0.55     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
cm1 = confusion_matrix(Y_test,Y_pred)

sns.heatmap(cm1, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for KNN',fontsize=17)
plt.show()

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, Y_train)
Y_pred = rf.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.97      0.78      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
cm2 = confusion_matrix(Y_test,Y_pred)

sns.heatmap(cm2, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Radom Forest',fontsize=17)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train, Y_train)

Y_pred = nb.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.15      0.63      0.24        98
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.81      0.62     56962
# weighted avg       1.00      0.99      1.00     56962

# %%
cm3 = confusion_matrix(Y_test,Y_pred)

sns.heatmap(cm3, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Naive Bayes',fontsize=17)
plt.show()

# %%
log = LogisticRegression()
log.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       1.00      0.05      0.10        98
#
#     accuracy                           1.00     56962
#    macro avg       1.00      0.53      0.55     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
cm4 = confusion_matrix(Y_test,Y_pred)

sns.heatmap(cm4, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Logistic Regression',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# %%
models = [('Logistic Regression', LogisticRegression()), 
          ('knn', KNeighborsClassifier()), 
          ('Random Forest', RandomForestClassifier()),
          ('Naive Bayes', GaussianNB())]

results = []

# %%
for model_name, model in models:
    scores = cross_val_score(model, X, Y, cv=5, scoring='f1_macro')
    results.append((model_name, scores))
    
fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot([score for _, score in results], labels=[model_name for model_name, _ in results])
ax.set_title('Machine Learning Models on Imbalanced Credit Card Fraud Dataset')
ax.set_ylabel('F1 Macro Score')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Testing model with new data

# %%
import pandas as pd
import joblib

# %%
knn = KNeighborsClassifier()


joblib.dump(knn, 'trained_knn.pkl')
# Out:
# ['trained_knn.pkl']

# %%
m = joblib.load('trained_knn.pkl')

# %%
data = pd.read_csv(r'/content/ccf.csv')

# %%
data
# Out:
#         distance_from_home  distance_from_last_transaction  \
# 0                57.877857                        0.311140
# 1                10.829943                        0.175592
# 2                 5.091079                        0.805153
# 3                 2.247564                        5.600044
# 4                44.190936                        0.566486
# ...                    ...                             ...
# 179747            1.806189                        2.792029
# 179748            0.521152                        1.910514
# 179749           34.473962                        9.667209
# 179750            0.982252                        2.304274
# 179751            9.541170                        0.187153
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 0                             1.945940                1          1
# 1                             1.294219                1          0
# ...

# %%
data.isna().sum()
# Out:
# distance_from_home                0
# distance_from_last_transaction    0
# ratio_to_median_purchase_price    0
# repeat_retailer                   0
# used_chip                         0
# used_pin_number                   0
# online_order                      1
# fraud                             1
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
import pandas as pd
import numpy as np

# %%
data = data[~np.isnan(data).any(axis=1)]

# %%
df.fillna(999, inplace=True)

# %%
data['fraud'].value_counts()
# Out:
# 0.0    164131
# 1.0     15620
# Name: fraud, dtype: int64

# %%
x_n = data.drop('fraud', axis=1)
y_n = data['fraud']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train_n, x_test_n, y_train_n, y_test_n = train_test_split(x_n, y_n, test_size=0.2, random_state=42)

# %%
knn.fit(x_train_n, y_train_n)
# Out:
# KNeighborsClassifier()

# %%
y_pred_n = knn.predict(x_test_n)

# %%
print(classification_report(y_test_n, y_pred_n))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98     32801
#          1.0       0.82      0.85      0.83      3150
#
#     accuracy                           0.97     35951
#    macro avg       0.90      0.92      0.91     35951
# weighted avg       0.97      0.97      0.97     35951

# %%
cm_n = confusion_matrix(y_test_n,y_pred_n)

sns.heatmap(cm_n, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for knn',fontsize=17)
plt.show()

# %%
nb = GaussianNB()
joblib.dump(knn, 'trained_nb.pkl')
# Out:
# ['trained_nb.pkl']

# %%
nb.fit(x_train_n, y_train_n)
# Out:
# GaussianNB()

# %%
y_pred_n = nb.predict(x_test_n)

# %%
print(classification_report(y_test_n, y_pred_n))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     32801
#          1.0       0.77      0.58      0.66      3150
#
#     accuracy                           0.95     35951
#    macro avg       0.87      0.78      0.82     35951
# weighted avg       0.94      0.95      0.95     35951

# %%
cm_n1 = confusion_matrix(y_test_n,y_pred_n)

sns.heatmap(cm_n1, annot=True, fmt='g')
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix for Naive Bayes',fontsize=17)
plt.show()
